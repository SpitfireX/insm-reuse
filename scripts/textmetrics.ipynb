# %%
import pandas as pd
import numpy as np
import plotly.express as px

import pathlib
import json

# %%
root = pathlib.Path('../quellen/artikel/extracted/')

metadata = pd.DataFrame()

for subdir in root.iterdir():
    name = subdir.name
    if subdir.is_dir():
        d = {
            'path': [],
            'title': [],
            'hash': [],
            'len': [],
        }

        for file in subdir.rglob('*.json'):
            with file.open(mode='r', encoding='utf-8') as f:
                j = json.load(f)
            d['path'].append(str(file))
            d['title'].append(j['title'])
            d['hash'].append(j['fingerprint'])
            d['len'].append(len(j['text']))

        df = pd.DataFrame(d)
        df['source'] = name
        metadata = metadata.append(df)

metadata.to_csv('text_metadata.csv')
metadata
# Out:
#                                                   path  \
# 0    ../quellen/artikel/extracted/BILD/json/7/OTY7b...
# 1    ../quellen/artikel/extracted/BILD/json/7/nlcPW...
# 2    ../quellen/artikel/extracted/BILD/json/7/Q75Ez...
# 3    ../quellen/artikel/extracted/BILD/json/7/IVCSD...
# 4    ../quellen/artikel/extracted/BILD/json/7/YJ59v...
# ..                                                 ...
# 822  ../quellen/artikel/extracted/zeitonline_wir/js...
# 823  ../quellen/artikel/extracted/zeitonline_wir/js...
# 824  ../quellen/artikel/extracted/zeitonline_wir/js...
# 825  ../quellen/artikel/extracted/zeitonline_wir/js...
# 826  ../quellen/artikel/extracted/zeitonline_wir/js...
#
#                                                  title  \
# 0       Abnehmen: Warum uns Diäten sogar dicker machen
# 1    Corona: Pandemie „hätte verhindert werden könn...
# 2    „Schlag den Star“: Schnupper-Debakel: Geiss ve...
# 3    Globus in Eschborn: Hier wächst ein 60-Mio.-Su...
# 4    Vatertag während Corona: Wo darf ich mit dem B...
# ..                                                 ...
# 822                                        ZEIT ONLINE
# 823                                        ZEIT ONLINE
# 824                                        ZEIT ONLINE
# 825                                        ZEIT ONLINE
# 826                                        ZEIT ONLINE
#
#                              hash   len          source
# 0    kYq6EEAgcYqFnadBpY8GQFQOV0g=  3197            BILD
# 1    jcTLw8Lkc18vhLQTNc3VHIrtlsA=  2958            BILD
# 2    H+k1PhGNSkoQoV6MftdT8ttYLUg=  3422            BILD
# 3    cXBTuwbbo08cRwr8wmgnft3Q82Q=   470            BILD
# 4    JPV/cr9GJ9E3LueHGg40/WIACqA=  5753            BILD
# ..                            ...   ...             ...
# 822  lAt+EOmSwBdFEVTQtILHWmSF4rk=   435  zeitonline_wir
# 823  lAt+EOmSwBdFEVTQtILHWmSF4rk=   435  zeitonline_wir
# 824  lAt+EOmSwBdFEVTQtILHWmSF4rk=   435  zeitonline_wir
# 825  lAt+EOmSwBdFEVTQtILHWmSF4rk=   435  zeitonline_wir
# 826  lAt+EOmSwBdFEVTQtILHWmSF4rk=   435  zeitonline_wir
#
# [151030 rows x 5 columns]

# %%
sources = metadata['source'].unique()
sources
# Out:
# array(['BILD', 'BILD_Politik', 'FAZ_Politik', 'FAZ_Wirtschaft',
#        'FOCUS_TopNews', 'INSMPresse', 'RND_de', 'RTLde',
#        'SPIEGEL_Politik', 'SZ', 'Tagesspiegel', 'derspiegel', 'faznet',
#        'focusfinanzen', 'focuspolitik', 'insm', 'ntvde', 'ntvde_Politik',
#        'sternde', 'tonline', 'zeitonline', 'zeitonline_pol', 'welt',
#        'zeitonline_wir'], dtype=object)

# %%
for source in sources:
    print(source)
    print('------------------')
    print(metadata[metadata['source'] == source].nunique())
    print('total:', metadata[metadata['source'] == source].shape[0])
    print('------------------')
# Out:
# BILD
# ------------------
# path      22733
# title     22150
# hash      22203
# len        5082
# source        1
# dtype: int64
# total: 22733
# ------------------
# BILD_Politik
# ------------------
# path      4782
# title     4748
# hash      4701
# len       3025
# source       1
# dtype: int64
# total: 4782
# ------------------
# FAZ_Politik
# ------------------
# path      5673
# title     5672
# hash      4431
# len       3128
# source       1
# dtype: int64
# total: 5673
# ------------------
# FAZ_Wirtschaft
# ------------------
# path      4231
# title     4229
# hash      3109
# len       2366
# source       1
# dtype: int64
# total: 4231
# ------------------
# FOCUS_TopNews
# ------------------
# path      11159
# title     10722
# hash      10452
# len        5192
# source        1
# dtype: int64
# total: 11159
# ------------------
# INSMPresse
# ------------------
# path      55
# title     49
# hash      49
# len       49
# source     1
# dtype: int64
# total: 55
# ------------------
# RND_de
# ------------------
# path      12418
# title     12362
# hash      12363
# len        5478
# source        1
# dtype: int64
# total: 12418
# ------------------
# RTLde
# ------------------
# path      180
# title     130
# hash      130
# len       129
# source      1
# dtype: int64
# total: 180
# ------------------
# SPIEGEL_Politik
# ------------------
# path      97
# title     97
# hash      97
# len       87
# source     1
# dtype: int64
# total: 97
# ------------------
# SZ
# ------------------
# path      9260
# title     9150
# hash      9155
# len       5049
# source       1
# dtype: int64
# total: 9260
# ------------------
# Tagesspiegel
# ------------------
# path      7931
# title     7781
# hash      7786
# len       4763
# source       1
# dtype: int64
# total: 7931
# ------------------
# derspiegel
# ------------------
# path      8793
# title     8744
# hash      8705
# len       4581
# source       1
# dtype: int64
# total: 8793
# ------------------
# faznet
# ------------------
# path      9611
# title     9469
# hash      7649
# len       4248
# source       1
# dtype: int64
# total: 9611
# ------------------
# focusfinanzen
# ------------------
# path      2101
# title     2049
# hash      2061
# len       1839
# source       1
# dtype: int64
# total: 2101
# ------------------
# focuspolitik
# ------------------
# path      2733
# title     2631
# hash      2634
# len       2318
# source       1
# dtype: int64
# total: 2733
# ------------------
# insm
# ------------------
# path      189
# title     168
# hash      165
# len       161
# source      1
# dtype: int64
# total: 189
# ------------------
# ntvde
# ------------------
# path      12910
# title     12385
# hash      12583
# len        5165
# source        1
# dtype: int64
# total: 12910
# ------------------
# ntvde_Politik
# ------------------
# path      184
# title     179
# hash      179
# len       177
# source      1
# dtype: int64
# total: 184
# ------------------
# sternde
# ------------------
# path      5085
# title     4967
# hash      4832
# len       3512
# source       1
# dtype: int64
# total: 5085
# ------------------
# tonline
# ------------------
# path      4722
# title     4343
# hash      4354
# len       3190
# source       1
# dtype: int64
# total: 4722
# ------------------
# zeitonline
# ------------------
# path      11098
# title        28
# hash         28
# len          28
# source        1
# dtype: int64
# total: 11098
# ------------------
# zeitonline_pol
# ------------------
# path      3958
# title        5
# hash         5
# len          5
# source       1
# dtype: int64
# total: 3958
# ------------------
# welt
# ------------------
# path      10300
# title     10122
# hash       9147
# len        5182
# source        1
# dtype: int64
# total: 10300
# ------------------
# zeitonline_wir
# ------------------
# path      827
# title       1
# hash        1
# len         1
# source      1
# dtype: int64
# total: 827
# ------------------

# %%
for source in sources:
    px.histogram(metadata[metadata['source'] == source], x='len', title=source).show()
